# %%
import pandas as pd
import re
from gensim.models.keyedvectors import KeyedVectors

# Train the model based on the Google News Vectors Dataset
def load_word2vec_model(file_name):
    return KeyedVectors.load_word2vec_format(file_name, binary=True)

# %%
# Getting the formatted data from a file
'''
    TODO: Add a format layout here
'''
def get_data(value):
    func = hasattr(value, "read") and (lambda x: x) or (lambda x: open(x))
    data = list()
    with func(value) as f:
        for line in f:
            print(line)

# %%
df = get_data('../Data/baseball/ari0814.csv')
# Out:
# MLB DIAMONDBACKS +145 ML 5u DIAMONDBACKS -135 RL 5u,0,0
#
# Top #MLB Pick 5: ARIZONA DIAMONDBACKS vsHOUSTON ASTROS go with #HOUSTONASTROS (-150) make picks free: http:// bit.ly/qQqhb7,0,0
#
# #Diamondbacks SP Jose Berrios 1B/DH Kendrys Morales #Giants SP Taijuan Walker RP Zach Duke OF Dexter Fowler,0,0
#
# Coming up: Major League Baseball Baseball - Arizona Diamondbacks @Houston Astros on BT Sport 2 (UK),0,0
#
# Vtg Matt Williams Arizona Diamondbacks jersey size xl $20 pic.twitter.com/TVcbispJFv,1,0
#
# I kind of liked the Diamondbacks tonight. Good luck to you Michael!,0,0
#
# Wow... the Diamond Club is so awesome GO!!! #Astros — attending Houston Astros vs. Arizona Diamondbacks at... http:// fb.me/1hYDBldri,0,0
#
# ENDS NOW FINAL BIDS! Check out Yasmany Tomas DIAMONDBACKS autograph OML Baseball COA Memorabilia Lane http://www. ebay.com/itm/Yasmany-To mas-DIAMONDBACKS-autograph-OML-Baseball-COA-Memorabilia-Lane-/253087556312?roken=cUgayN&soutkn=TqZAa7 … via @eBay,0,0
#
# ...
